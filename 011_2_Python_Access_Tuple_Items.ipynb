# %% [markdown]
# # Python - การเข้าถึง Tuple

# %% [markdown]
# ##การเข้าถึง Tuple
# เราสามารถเข้าถึง tuple โดยการใช้เลข index ใส่ใน [ ] :

# %% [markdown]
# ## ตัวอย่าง
#
# แสดงค่าลำดับที่ 3 ใน tuple :
#
# Note: index แรก คือ 0

# %%
foodtuple = ("Sushi", "Burger", "Salad")
print(foodtuple[2])
# Out:
# banana

# %% [markdown]
# ## Negative Indexing
# Negative indexing คือ การเริ่มต้น index จากส่วนท้าย
#
# -1 คือ ตัวสุดท้าย , -2 คือ ตัวรองสุดท้าย , ฯลฯ

# %% [markdown]
# ## ตัวอย่าง
#
# แสดงค่าสุดท้ายของ tuple :

# %%
foodtuple = ("Sushi", "Burger", "Salad")
print(foodtuple[-1])
# Out:
# cherry

# %% [markdown]
# ##ช่วงของ Indexes
#
# เราสามารถระบุเป็นช่วงของ index ว่าเริ่มที่ไหนและจบที่ไหน
#
# โดยการระบุเป็นช่วงของ index นั้น จะมีการส่งคืนค่ามาเป็น tuple ใหม่ที่มีรายการตามที่ระบุ

# %% [markdown]
# ## ตัวอย่าง
#
# ส่งคืนค่าลำดับที่ 2 ,3 ,4 :
#
# Note: การระบุ index เพื่อส่งคืนค่า index ที่ 1 (รวมอยู่ด้วย) และ index สุดท้าย index ที่ 4 (ไม่รวมอยู่ด้วย)
#
# **อย่าลืมว่า รายการแรกมี index คือ 0

# %%
foodtuple = ("Sushi", "Burger", "Salad", "Pizza", "Noodle", "Curry", "Soup")
print(foodtuple[1:4])
# Out:
# ('cherry', 'orange', 'kiwi')

# %% [markdown]
# การไม่ระบุค่าเริ่มต้น คือ การเริ่มเอาตั้งแต่ค่าแรก

# %% [markdown]
# ## ตัวอย่าง
# จากตัวอย่างจะส่งคืนค่าตั้งแต่ค่าเริ่มต้นจนถึงค่า index ที่ 2 ไม่รวม Pizza :

# %%
foodtuple = ("Sushi", "Burger", "Salad", "Pizza", "Noodle", "Curry", "Soup")
print(foodtuple[:3])
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %% [markdown]
# การไม่ระบุค่าสุดท้าย คือ การเอาค่าตั้งแต่ที่กำหนดถึงค่าสุดท้ายของรายการ

# %% [markdown]
# ##ตัวอย่าง
# จากตัวอย่างเป็นการส่งคืนค่าตั้งแต่ Salad ไปจนถึงตัวสุดท้ายของรายการ :

# %%
foodtuple = ("Sushi", "Burger", "Salad", "Pizza", "Noodle", "Curry", "Soup")
print(foodtuple[2:])
# Out:
# ('cherry', 'orange', 'kiwi', 'melon', 'mango')

# %% [markdown]
# ##ช่วงของ Negative Indexes
# การระบุ negative indexes เราต้องระบุค่าเริ่มต้นที่ต้องการหาเป็นค่าสุดท้ายของ tuple :

# %% [markdown]
# ## ตัวอย่าง
# จากตัวอย่างเป็นการส่งคืนค่าของ index ที่ -4 (รวมอยู่ด้วย) ถึงค่าของ index ที่ -1 (ไม่รวมอยู่ด้วย)

# %%
foodtuple = ("Sushi", "Burger", "Salad", "Pizza", "Noodle", "Curry", "Soup")
print(foodtuple[-4:-1])
# Out:
# ('orange', 'kiwi', 'melon')

# %% [markdown]
# ## ตรวจสอบว่ามีรายการนี้อยู่หรือไม่
# การตรวจสอบว่ามีรายการนี้อยู่ใน tuple หรือไม่ สามารถใช้คำสั่ง in ในการตรวจสอบได้ :

# %% [markdown]
# ##ตัวอย่าง
# จงตรวจสอบว่ามี Pizza อยู่ใน tuple นี้หรือไม่ :

# %%
foodtuple = ("Sushi", "Burger", "Salad", "Pizza", "Noodle", "Curry", "Soup")
if "Pizza" in foodtuple:
  print("Yes, 'Pizza' is in the food tuple")
# Out:
# Yes, 'apple' is in the fruits tuple
