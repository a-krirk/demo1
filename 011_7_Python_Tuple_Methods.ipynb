# %% [markdown]
# # Python - Tuple Methods

# %% [markdown]
# ## Tuple Methods
# Python มี 2 medthods ที่สามารถใช้กับ tuple ได้

# %% [markdown]
# คำอธิบาย Method
#
# count() แสดงจำนวนของค่าที่ค้นหาที่มีใน tuple
# index() ส่งคืนค่า index ใน tuple ของค่าที่ค้นหา
