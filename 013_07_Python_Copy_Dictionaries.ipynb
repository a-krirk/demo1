# %% [markdown]
# # Python - การคัดลอก Dictionaries

# %% [markdown]
# ## การคัดลอก dictionary
# ไม่สามารถคัดลอกได้ง่าย ๆ ด้วยการใช้เครื่องหมายเท่ากับ เช่น  dict2 = dict1
# เพราะ dict2 จะอ้างอิงกับ dict1 และการเปลี่ยนแปลงที่เกิดขึ้นใน dict1 จะลงผลกับ dict2 อัตโนมัติ

# %% [markdown]
# ### ตัวอย่าง
# ใช้ method **copy()** คัดลอก dictionary

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = thisdict.copy()
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %% [markdown]
# ใช้ built-in function **dict()** คัดลอก dictionary ได้เช่นกัน

# %% [markdown]
# ### ตัวอย่าง
# ใช้ function **dict()** คัดลอก dictionary

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = dict(thisdict)
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}
