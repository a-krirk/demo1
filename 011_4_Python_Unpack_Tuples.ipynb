# %% [markdown]
# # Python - Unpack Tuples

# %% [markdown]
# ## Unpacking a Tuple
#
# เมื่อเราสร้าง tuple เป็นปกติที่เราจะมีการกำหนดค่าให้ ซึ่งเราจะเรียกว่า "packing" :

# %% [markdown]
# ## ตัวอย่าง
# Packing a tuple:

# %%
food = ("Sushi", "Burger", "Papaya salad")

# %% [markdown]
# ใน python เราจะอนุญาตให้สามารถกระจายค่าแล้วกลับไปเป็นตัวแปรได้ เรียกว่า  "unpacking":

# %% [markdown]
# ## ตัวอย่าง
# Unpacking a tuple:
#
# Note:จำนวนของตัวแปรจำเป็นที่จะต้องเท่ากับจำนวนของค่าที่มีใน tuple มิฉะนั้นเราจำเป็นที่จะต้องใช้เครื่องหมาย * เพื่อรวบรวมค่าที่เหลือเข้าไว้ใน list

# %%
food = ("Sushi", "Burger", "Papaya salad")

(Japan, Amarica, Thai) = food

print(Japan)
print(Amarica)
print(Thai)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ##การใช้เครื่องหมาย *
# ถ้าจำนวนของตัวแปรมีน้อยกว่าจำนวนของค่าใน tuple เราสามารถใช้เครื่องหมาย * ใส่ไว้ด้านหน้าชื่อตัวแปร แล้วค่าที่เหลือจะถูกจัดเก็บอยู่ในตัวแปรนี้ในรูปของ list :

# %% [markdown]
# ## ตัวอย่าง
# กำหนดให้ค่าที่เหลือเก็บอยู่ใน list ที่ชื่อ "Thai"
# Assign the rest of the values as a list called "red":

# %%
food = ("Sushi", "Burger", "Papaya salad", "Pizza", "Noodle", "Curry", "Soup")

(Japan, Amarica, *Thai) = food

print(Japan)
print(Amarica)
print(Thai)
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'raspberry']

# %% [markdown]
# ถ้าหากมีการใช้เครื่องหมาย * กับตัวแปรอื่นก่อนตัวแปรสุดท้าย python จะกำหนดค่าให้กับตัวแปรจนกว่าจำนวนตัวแปรที่เหลือจะมีค่าเท่ากับจำนวนตัวแปรที่เหลือ

# %% [markdown]
# ##ตัวอย่าง
# เพิ่ม list ของค่าให้กับตัวแปรชื่อ "Thai" :

# %%
food = ("Sushi", "Burger", "Papaya salad", "Tom Yum Goong", "Pad Thai", "Noodle")

(Japan, Amarica, *Thai, China) = food

print(Japan)
print(Amarica)
print(Thai)
print(China)
# Out:
# apple
# ['mango', 'papaya', 'pineapple']
# cherry
