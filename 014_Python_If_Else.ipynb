# %% [markdown]
# ##Python If ... Else

# %% [markdown]
# ##Python เงื่อนไข และการใช้คำสั่ง If
# Python รองรับเงื่อนไขตรรกะปกติจากคณิตศาสตร์:
#
#
# * เท่ากับ: **a == b**
# * น้อยกว่า: **a < b**
# * ไม่เท่ากับ: **a != b**
# * น้อยกว่าหรือเท่ากับ: **a <= b**
# * มากกว่า: **a > b**
# * มากกว่าหรือเท่ากับ: **a >= b**
# เงื่อนไขเหล่านี้สามารถใช้ได้หลายวิธี โดยทั่วไปจะใช้ใน "คำสั่ง if" และลูป
#
# "คำสั่ง if" เขียนโดยใช้คีย์เวิร์ด **if**

# %% [markdown]
# ## ตัวอย่าง
# คำสั่ง If

# %%
a = 33
b = 200
if b > a:
  print("b มากกว่า a")
# Out:
# b is greater than a

# %% [markdown]
# ในตัวอย่างนี้เราใช้ตัวแปรสองตัวคือ a และ b ซึ่งใช้เป็นส่วนหนึ่งของคำสั่ง if เพื่อทดสอบว่า b มากกว่า a เนื่องจาก a คือ 33 และ b คือ 200 เรารู้ว่า 200 มากกว่า 33 ดังนั้นเราจึงพิมพ์ไปที่หน้าจอว่า "b มากกว่า a"

# %% [markdown]
# ## Elif
#
# คีย์เวิร์ด **elif** เป็นวิธีของ pythons ที่พูดว่า "หากเงื่อนไขก่อนหน้านี้ไม่เป็นความจริง ให้ลองใช้เงื่อนไขนี้"

# %% [markdown]
# ##ตัวอย่าง

# %%
a = 33
b = 33
if b > a:
  print("b มากกว่า a")
elif a == b:
  print("a เท่ากับ b")
# Out:
# a and b are equal

# %% [markdown]
# ในตัวอย่างนี้ **a** เท่ากับ **b** ดังนั้นเงื่อนไขแรกไม่เป็นความจริง แต่เงื่อนไข **elif** เป็นจริง ดังนั้นเราจึงพิมพ์ไปที่หน้าจอว่า "a เท่ากับ b "

# %% [markdown]
# ## Else
# คีย์เวิร์ด **else** จะทำตามเงื่อนไขอื่นทั้งหมด ที่ไม่เป็นไปตามเงื่อนไขก่อนหน้านี้

# %% [markdown]
# ## ตัวอย่าง

# %%
a = 200
b = 33
if b > a:
  print("b มากกว่า a")
elif a == b:
  print("a เท่ากับ b")
else:
  print("a มากกว่า b")
# Out:
# a is greater than b

# %% [markdown]
# ในตัวอย่างนี้ a มากกว่า b ดังนั้นเงื่อนไขแรกไม่เป็นความจริง เงื่อนไข elif ก็ไม่เป็นจริงด้วย ดังนั้นเราจึงไปที่เงื่อนไข else และพิมพ์ไปที่หน้าจอว่า "a มากกว่า b"
#
# คุณสามารถใช้ **else** ได้ โดยไม่ต้องใช้**elif**

# %% [markdown]
# ## ตัวอย่าง

# %%
a = 60
b = 40
if b > a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# b is not greater than a

# %% [markdown]
# ## การย่อคำสั่ง if
# คำสั่ง if 1 บรรทัด

# %%
if a > b: print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# ## การย่อคำสั่ง If ... Else
# หากคุณมีเพียงหนึ่งคำสั่งที่จะดำเนินการ หนึ่งคำสั่งสำหรับ if และอีกหนึ่งคำสั่งสำหรับคำสั่งอื่น คุณสามารถรวมทั้งหมดไว้ในบรรทัดเดียวกัน:

# %% [markdown]
# ## ตัวอย่าง
# คำสั่ง if else 1 บรรทัด:

# %%
a = 200
b = 335
print("A") if a > b else print("B")
# Out:
# B

# %% [markdown]
# คุณยังสามารถมีคำสั่ง else หลายรายการในบรรทัดเดียวกันได้:

# %% [markdown]
# ## ตัวอย่าง
# คำสั่ง if else หนึ่งบรรทัด โดยมี 3 เงื่อนไข:

# %%
a = 330
b = 330
print("A") if a > b else print("=") if a == b else print("B")
# Out:
# =

# %% [markdown]
# And
# คีย์เวิร์ด and เป็นโอเปอเรเตอร์เชิงตรรกะ และใช้เพื่อรวมคำสั่งแบบมีเงื่อนไข:

# %% [markdown]
# ##ตัวอย่าง
#
# ทดสอบว่า a มากกว่า b และถ้า c มากกว่า a

# %%
a = 255
b = 355
c = 555
if a > b and c > a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %% [markdown]
# ## Or
# คีย์เวิร์ด **or** เป็นโอเปอเรเตอร์เชิงตรรกะ และใช้เพื่อรวมคำสั่งแบบมีเงื่อนไข:

# %% [markdown]
# ## ตัวอย่าง
# ทดสอบว่า **a** มากกว่า **b** หรือถ้า **a** มากกว่า **c**:

# %%
a = 255
b = 355
c = 555
if a > b or a > c:
  print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %% [markdown]
# ## Nested If
# คุณสามารถมีคำสั่ง if ภายใน if คำสั่ง ซึ่งเรียกว่า nested if

# %% [markdown]
# ## ตัวอย่าง

# %%
x = 77

if x > 17:
  print("Above seventeen,")
  if x > 70:
    print("and also above 70!")
  else:
    print("but not above 70.")
# Out:
# Above ten,
# and also above 20!

# %% [markdown]
# ## คำสั่ง pass
#
# หากข้อความสั่งไม่สามารถว่างเปล่าได้ แต่ถ้าคุณมีเหตุผลบางอย่างที่มีคำสั่ง if ที่ไม่มีเนื้อหา ให้ใส่คำสั่ง pass เพื่อหลีกเลี่ยงข้อผิดพลาด

# %% [markdown]
# ## ตัวอย่าง

# %%
a = 355
b = 255

if b > a:
  pass
