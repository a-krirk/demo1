# %% [markdown]
# # Python - ลบข้อมูลใน Set

# %% [markdown]
# ## การลบข้อมูล
# การลบข้อมูลใน set สามารถใช้คำสั่ง remove() หรือ discard()

# %% [markdown]
# ## ตัวอย่าง
# ลบ "Burger" โดยใช้คำสั่ง remove() :
#
# Note: ถ้าหากข้อมูลที่ต้องการลบไม่มีอยู่ใน set คำสั่ง remove() จะเกิด error

# %%
foodset = {"Sushi", "Burger", "Salad"}

foodset.remove("Burger")

print(foodset)
# Out:
# {'apple', 'cherry'}

# %% [markdown]
# ## ตัวอย่าง
# ลบ "Burger" โดยใช้คำสั่ง discard() :
#
# Note: ถ้าหากข้อมูลที่ต้องการลบไม่มีใน set คำสั่ง discard() จะไม่เกิด error

# %%
foodset = {"Sushi", "Burger", "Salad"}

foodset.discard("Burger")

print(foodset)
# Out:
# {'apple', 'cherry'}

# %% [markdown]
# เราสามารถใช้คำสั่ง pop() เพื่อลบข้อมูล แต่คำสั่งนี้จะทำการลบข้อมูลล่าสุดเท่านั้น จำไว้ว่า set เป็นข้อมูลที่ไม่มีลำดับ ดังนั้นเราจะไม่รู้ว่าข้อมูลใดที่ถูกลบ

# %% [markdown]
# ## ตัวอย่าง
# ลบข้อมูลล่าสุดโดยใช้คำสั่ง pop():
#
# Note:set เป็นข้อมูลที่ไม่มีลำดับ ดังนั้น เมื่อเราใช้คำสั่ง pop() เราจะไม่รู้ว่าข้อมูลใดถูกลบ

# %%
foodset = {"Sushi", "Burger", "Salad"}

x = foodset.pop()

print(x)

print(foodset)
# Out:
# banana
# {'apple', 'cherry'}

# %% [markdown]
# ## ตัวอย่าง
# ใช้คำสั่ง clear() เพื่อลบข้อมูลทั้งหมดใน set:

# %%
foodset = {"Sushi", "Burger", "Salad"}

foodset.clear()

print(foodset)
# Out:
# set()

# %% [markdown]
# ## ตัวอย่าง
# ใช้คำสั่ง del เพื่อลบ set:

# %%
foodset = {"Sushi", "Burger", "Salad"}

del foodset

print(foodset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b3c23c8906da> in <module>
#       3 del thisset
#       4
# ----> 5 print(thisset)
#
# NameError: name 'thisset' is not defined
