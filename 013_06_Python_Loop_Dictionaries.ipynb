# %% [markdown]
# # Python - การใช้ Loop กับ Dictionaries

# %% [markdown]
# ## การใช้ Loop กับ Dictionaries
# สามารถ loop หรือประมวลผลแบบวนซ้ำได้ด้วยการใช้ for loop
# โดยจะได้ค่ากลับมาเป็น key หรือ value ของ dictionary
#
# การทำ for loop สามารถทำได้หลายวิธี

# %% [markdown]
# ### ตัวอย่าง
# ปริ้นชื่อ key ทั้งหมดใน dictionary ด้วย for loop

# %%
thisdict = {'Jared':'Leadership','Sian':'Prosperity','Hayley':'Hope','Christopher':'Generostiy'}

# %%
for x in thisdict:
  print(x)
# Out:
# Jared
# Sian
# Hayley
# Christopher

# %% [markdown]
# ### ตัวอย่าง
# ปริ้น value ทั้งหมดใน dictionary ด้วย for loop

# %%
for x in thisdict:
  print(thisdict[x])
# Out:
# Leadership
# Prosperity
# Hope
# Generostiy

# %% [markdown]
# ### ตัวอย่าง
# ใช้ method **values()** เพื่อปริ้น value ทั้งหมดใน dictionary ด้วย for loop

# %%
for x in thisdict.values():
  print(x)
# Out:
# Leadership
# Prosperity
# Hope
# Generostiy

# %% [markdown]
# ### ตัวอย่าง
# ใช้ method **keys()** เพื่อปริ้น key ทั้งหมดใน dictionary ด้วย for loop

# %%
for x in thisdict.keys():
  print(x)
# Out:
# Jared
# Sian
# Hayley
# Christopher

# %% [markdown]
# ### ตัวอย่าง
# ใช้ method **items()** เพื่อปริ้น key และ value ทั้งหมดใน dictionary ด้วย for loop

# %%
for x, y in thisdict.items():
  print(x, y)
# Out:
# Jared Leadership
# Sian Prosperity
# Hayley Hope
# Christopher Generostiy
