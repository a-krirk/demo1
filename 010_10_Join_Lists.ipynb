# %% [markdown]
# # Python - การ Join Lists

# %% [markdown]
# ## Join 2 Lists
# มีหลายวิธีที่สามารถรวม item ของ list 2 อันไว้รวมกันได้
# วิธีที่ง่ายที่สุดคือการใช้เครื่องหมาย **+**

# %% [markdown]
# ### ตัวอย่าง
# รวม list 2 อันไว้ด้วยกัน

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %% [markdown]
# มีอีกวิธีที่รวม item ของ list ทั้งสองอันได้ โดยการ append item ทั้งหมดจาก list2 มายัง list1 ทีละ item

# %% [markdown]
# ### ตัวอย่าง
# Append list2 ไปใน list1

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

for x in list2:
  list1.append(x)

print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %% [markdown]
# สามารถใช้ method **extend()** ได้เช่นเดียวกัน

# %% [markdown]
# ### ตัวอย่าง
# ใช้ method **extend()** เพิ่ม item ของ list2 ไปใน list1

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

list1.extend(list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]
